# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import tensorflow_datasets as tfds

# %%
import urllib3
urllib3.disable_warnings()

#tfds.disable_progress_bar()   # 이 주석을 풀면 데이터셋 다운로드과정의 프로그레스바가 나타나지 않습니다.

(ds_train, ds_test), ds_info = tfds.load(
    'cifar10',
    split=['train', 'test'],
    shuffle_files=True,
    with_info=True,
)

# %%
def normalize_and_resize_img(image, label):
    """Normalizes images: `uint8` -> `float32`."""
    # image = tf.image.resize(image, [32, 32])
    return tf.cast(image, tf.float32) / 255., label

# %%
def apply_normalize_on_dataset(ds, is_test=False, batch_size=16):
    ds = ds.map(
        normalize_and_resize_img, 
        num_parallel_calls=1
    )
    ds = ds.batch(batch_size)
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
class VGG16_conv1(tf.keras.Model):
    def __init__(self):
        super(VGG16_conv1,self).__init__()
        self.conv1_1 = tf.keras.layers.Conv2D(64, kernel_size=3, strides=1, padding='same',activation='relu')
        self.conv1_2 = tf.keras.layers.Conv2D(64, kernel_size=3, strides=1, padding='same',activation='relu')
        self.maxpool1 = tf.keras.layers.MaxPool2D(pool_size=2)
        
        self.conv2_1 = tf.keras.layers.Conv2D(128, kernel_size=3, strides=1, padding='same',activation='relu')
        self.conv2_2 = tf.keras.layers.Conv2D(128, kernel_size=3, strides=1, padding='same',activation='relu')
        self.maxpool2 = tf.keras.layers.MaxPool2D(pool_size=2)
        
        self.conv3_1 = tf.keras.layers.Conv2D(256, kernel_size=3, strides=1, padding='same',activation='relu')
        self.conv3_2 = tf.keras.layers.Conv2D(256, kernel_size=3, strides=1, padding='same',activation='relu')
        self.conv3_3 = tf.keras.layers.Conv2D(256, kernel_size=1, strides=1, padding='same',activation='relu')
        self.maxpool3 = tf.keras.layers.MaxPool2D(pool_size=2)
        
        self.conv4_1 = tf.keras.layers.Conv2D(512, kernel_size=3, strides=1, padding='same',activation='relu')
        self.conv4_2 = tf.keras.layers.Conv2D(512, kernel_size=3, strides=1, padding='same',activation='relu')
        self.conv4_3 = tf.keras.layers.Conv2D(512, kernel_size=1, strides=1, padding='same',activation='relu')
        self.maxpool4 = tf.keras.layers.MaxPool2D(pool_size=2)
        
        self.conv5_1 = tf.keras.layers.Conv2D(512, kernel_size=3, strides=1, padding='same',activation='relu')
        self.conv5_2 = tf.keras.layers.Conv2D(512, kernel_size=3, strides=1, padding='same',activation='relu')
        self.conv5_3 = tf.keras.layers.Conv2D(512, kernel_size=1, strides=1, padding='same',activation='relu')
        self.maxpool5 = tf.keras.layers.MaxPool2D(pool_size=2)

        self.gap = tf.keras.layers.GlobalAveragePooling2D()
        self.fc1 = tf.keras.layers.Dense(4096, activation='relu')
        self.fc2 = tf.keras.layers.Dense(4096, activation='relu')
        self.fc3 = tf.keras.layers.Dense(10, activation='softmax')        
        
    def call(self, input_tensor):
        x = self.conv1_1(input_tensor)
        x = self.conv1_2(x)
        x = self.maxpool1(x)
        
        x = self.conv2_1(x)
        x = self.conv2_2(x)
        x = self.maxpool2(x)
        
        x = self.conv3_1(x)
        x = self.conv3_2(x)
        x = self.conv3_3(x)
        x = self.maxpool3(x)
        
        x = self.conv4_1(x)
        x = self.conv4_2(x)
        x = self.conv4_3(x)
        x = self.maxpool4(x)
        
        x = self.conv5_1(x)
        x = self.conv5_2(x)
        x = self.conv5_3(x)
        x = self.maxpool5(x)
        
        x = self.gap(x)
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.fc3(x)
        return x

# %%
BATCH_SIZE = 256
EPOCH = 20

(ds_train, ds_test), ds_info = tfds.load(
    'cifar10',
    split=['train', 'test'],
    as_supervised=True,
    shuffle_files=True,
    with_info=True,
)
ds_train = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE)
ds_test = apply_normalize_on_dataset(ds_test, batch_size=BATCH_SIZE)

# %%
vgg16_conv1 = VGG16_conv1()

vgg16_conv1.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_16_conv1 = vgg16_conv1.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['test'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1
)
# Out:
# Epoch 1/20
# 195/195 [==============================] - 12s 61ms/step - loss: 2.3025 - accuracy: 0.1036 - val_loss: 2.3024 - val_accuracy: 0.1004
# Epoch 2/20
# 195/195 [==============================] - 11s 54ms/step - loss: 2.3024 - accuracy: 0.1030 - val_loss: 2.3023 - val_accuracy: 0.1012
# Epoch 3/20
# 195/195 [==============================] - 11s 55ms/step - loss: 2.3023 - accuracy: 0.1034 - val_loss: 2.3022 - val_accuracy: 0.0987
# Epoch 4/20
# 195/195 [==============================] - 10s 53ms/step - loss: 2.3022 - accuracy: 0.1208 - val_loss: 2.3021 - val_accuracy: 0.1545
# Epoch 5/20
# 195/195 [==============================] - 11s 54ms/step - loss: 2.3020 - accuracy: 0.1328 - val_loss: 2.3018 - val_accuracy: 0.1133
# Epoch 6/20
# 195/195 [==============================] - 11s 54ms/step - loss: 2.3019 - accuracy: 0.1290 - val_loss: 2.3018 - val_accuracy: 0.1671
# Epoch 7/20
# 195/195 [==============================] - 11s 54ms/step - loss: 2.3017 - accuracy: 0.1378 - val_loss: 2.3015 - val_accuracy: 0.1816
# Epoch 8/20
# 195/195 [==============================] - 10s 53ms/step - loss: 2.3014 - accuracy: 0.1449 - val_loss: 2.3011 - val_accuracy: 0.1928
# Epoch 9/20
# 195/195 [==============================] - 10s 54ms/step - loss: 2.3009 - accuracy: 0.1388 - val_loss: 2.3006 - val_accuracy: 0.1310
# Epoch 10/20
# 195/195 [==============================] - 11s 54ms/step - loss: 2.3003 - accuracy: 0.1530 - val_loss: 2.2998 - val_accuracy: 0.1700
# Epoch 11/20
# 195/195 [==============================] - 11s 54ms/step - loss: 2.2992 - accuracy: 0.1880 - val_loss: 2.2986 - val_accuracy: 0.1857
# Epoch 12/20
# 195/195 [==============================] - 11s 54ms/step - loss: 2.2975 - accuracy: 0.1844 - val_loss: 2.2962 - val_accuracy: 0.2125
# Epoch 13/20
# 195/195 [==============================] - 10s 52ms/step - loss: 2.2943 - accuracy: 0.1992 - val_loss: 2.2918 - val_accuracy: 0.1778
# Epoch 14/20
# 195/195 [==============================] - 11s 54ms/step - loss: 2.2881 - accuracy: 0.1891 - val_loss: 2.2829 - val_accuracy: 0.1989
# Epoch 15/20
# 195/195 [==============================] - 10s 53ms/step - loss: 2.2738 - accuracy: 0.1998 - val_loss: 2.2590 - val_accuracy: 0.1904
# Epoch 16/20
# 195/195 [==============================] - 10s 52ms/step - loss: 2.2215 - accuracy: 0.1826 - val_loss: 2.1767 - val_accuracy: 0.1745
# Epoch 17/20
# 195/195 [==============================] - 11s 54ms/step - loss: 2.1462 - accuracy: 0.1922 - val_loss: 2.1148 - val_accuracy: 0.2178
# Epoch 18/20
# 195/195 [==============================] - 10s 53ms/step - loss: 2.0939 - accuracy: 0.2157 - val_loss: 2.0902 - val_accuracy: 0.2282
# Epoch 19/20
# 195/195 [==============================] - 10s 52ms/step - loss: 2.0544 - accuracy: 0.2358 - val_loss: 2.0377 - val_accuracy: 0.2349
# Epoch 20/20
# 195/195 [==============================] - 10s 53ms/step - loss: 2.0313 - accuracy: 0.2421 - val_loss: 2.0136 - val_accuracy: 0.2538
