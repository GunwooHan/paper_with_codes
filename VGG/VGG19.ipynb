# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import tensorflow_datasets as tfds

# %%
import urllib3
urllib3.disable_warnings()

#tfds.disable_progress_bar()   # 이 주석을 풀면 데이터셋 다운로드과정의 프로그레스바가 나타나지 않습니다.

(ds_train, ds_test), ds_info = tfds.load(
    'cifar10',
    split=['train', 'test'],
    shuffle_files=True,
    with_info=True,
)

# %%
def normalize_and_resize_img(image, label):
    """Normalizes images: `uint8` -> `float32`."""
    # image = tf.image.resize(image, [32, 32])
    return tf.cast(image, tf.float32) / 255., label

# %%
def apply_normalize_on_dataset(ds, is_test=False, batch_size=16):
    ds = ds.map(
        normalize_and_resize_img, 
        num_parallel_calls=1
    )
    ds = ds.batch(batch_size)
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
class VGG19(tf.keras.Model):
    def __init__(self):
        super(VGG19,self).__init__()
        self.conv1_1 = tf.keras.layers.Conv2D(64, kernel_size=3, strides=1, padding='same',activation='relu')
        self.conv1_2 = tf.keras.layers.Conv2D(64, kernel_size=3, strides=1, padding='same',activation='relu')
        self.maxpool1 = tf.keras.layers.MaxPool2D(pool_size=2)
        
        self.conv2_1 = tf.keras.layers.Conv2D(128, kernel_size=3, strides=1, padding='same',activation='relu')
        self.conv2_2 = tf.keras.layers.Conv2D(128, kernel_size=3, strides=1, padding='same',activation='relu')
        self.maxpool2 = tf.keras.layers.MaxPool2D(pool_size=2)
        
        self.conv3_1 = tf.keras.layers.Conv2D(256, kernel_size=3, strides=1, padding='same',activation='relu')
        self.conv3_2 = tf.keras.layers.Conv2D(256, kernel_size=3, strides=1, padding='same',activation='relu')
        self.conv3_3 = tf.keras.layers.Conv2D(256, kernel_size=1, strides=1, padding='same',activation='relu')
        self.maxpool3 = tf.keras.layers.MaxPool2D(pool_size=2)
        
        self.conv4_1 = tf.keras.layers.Conv2D(512, kernel_size=3, strides=1, padding='same',activation='relu')
        self.conv4_2 = tf.keras.layers.Conv2D(512, kernel_size=3, strides=1, padding='same',activation='relu')
        self.conv4_3 = tf.keras.layers.Conv2D(512, kernel_size=1, strides=1, padding='same',activation='relu')
        self.maxpool4 = tf.keras.layers.MaxPool2D(pool_size=2)
        
        self.conv5_1 = tf.keras.layers.Conv2D(512, kernel_size=3, strides=1, padding='same',activation='relu')
        self.conv5_2 = tf.keras.layers.Conv2D(512, kernel_size=3, strides=1, padding='same',activation='relu')
        self.conv5_3 = tf.keras.layers.Conv2D(512, kernel_size=1, strides=1, padding='same',activation='relu')
        self.maxpool5 = tf.keras.layers.MaxPool2D(pool_size=2)

        self.gap = tf.keras.layers.GlobalAveragePooling2D()
        self.fc1 = tf.keras.layers.Dense(4096, activation='relu')
        self.fc2 = tf.keras.layers.Dense(4096, activation='relu')
        self.fc3 = tf.keras.layers.Dense(10, activation='softmax')        
        
    def call(self, input_tensor):
        x = self.conv1_1(input_tensor)
        x = self.conv1_2(x)
        x = self.maxpool1(x)
        
        x = self.conv2_1(x)
        x = self.conv2_2(x)
        x = self.maxpool2(x)
        
        x = self.conv3_1(x)
        x = self.conv3_2(x)
        x = self.conv3_3(x)
        x = self.maxpool3(x)
        
        x = self.conv4_1(x)
        x = self.conv4_2(x)
        x = self.conv4_3(x)
        x = self.maxpool4(x)
        
        x = self.conv5_1(x)
        x = self.conv5_2(x)
        x = self.conv5_3(x)
        x = self.maxpool5(x)
        
        x = self.gap(x)
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.fc3(x)
        return x

# %%
BATCH_SIZE = 256
EPOCH = 20

(ds_train, ds_test), ds_info = tfds.load(
    'cifar10',
    split=['train', 'test'],
    as_supervised=True,
    shuffle_files=True,
    with_info=True,
)
ds_train = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE)
ds_test = apply_normalize_on_dataset(ds_test, batch_size=BATCH_SIZE)

# %%
vgg19 = VGG19()

vgg19.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_19 = vgg19.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['test'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1
)
# Out:
# Epoch 1/20
# 195/195 [==============================] - 12s 61ms/step - loss: 2.3025 - accuracy: 0.1017 - val_loss: 2.3024 - val_accuracy: 0.0991
# Epoch 2/20
# 195/195 [==============================] - 11s 55ms/step - loss: 2.3024 - accuracy: 0.1140 - val_loss: 2.3023 - val_accuracy: 0.1726
# Epoch 3/20
# 195/195 [==============================] - 10s 54ms/step - loss: 2.3023 - accuracy: 0.1144 - val_loss: 2.3022 - val_accuracy: 0.0983
# Epoch 4/20
# 195/195 [==============================] - 11s 55ms/step - loss: 2.3022 - accuracy: 0.1163 - val_loss: 2.3021 - val_accuracy: 0.1314
# Epoch 5/20
# 195/195 [==============================] - 11s 54ms/step - loss: 2.3021 - accuracy: 0.1164 - val_loss: 2.3020 - val_accuracy: 0.1531
# Epoch 6/20
# 195/195 [==============================] - 11s 54ms/step - loss: 2.3019 - accuracy: 0.1345 - val_loss: 2.3018 - val_accuracy: 0.1612
# Epoch 7/20
# 195/195 [==============================] - 10s 53ms/step - loss: 2.3017 - accuracy: 0.1320 - val_loss: 2.3015 - val_accuracy: 0.1632
# Epoch 8/20
# 195/195 [==============================] - 10s 53ms/step - loss: 2.3014 - accuracy: 0.1619 - val_loss: 2.3011 - val_accuracy: 0.1504
# Epoch 9/20
# 195/195 [==============================] - 11s 54ms/step - loss: 2.3009 - accuracy: 0.1407 - val_loss: 2.3006 - val_accuracy: 0.1391
# Epoch 10/20
# 195/195 [==============================] - 10s 53ms/step - loss: 2.3002 - accuracy: 0.1672 - val_loss: 2.2997 - val_accuracy: 0.2169
# Epoch 11/20
# 195/195 [==============================] - 10s 54ms/step - loss: 2.2992 - accuracy: 0.1836 - val_loss: 2.2982 - val_accuracy: 0.1936
# Epoch 12/20
# 195/195 [==============================] - 11s 54ms/step - loss: 2.2975 - accuracy: 0.1880 - val_loss: 2.2960 - val_accuracy: 0.2072
# Epoch 13/20
# 195/195 [==============================] - 11s 55ms/step - loss: 2.2944 - accuracy: 0.1962 - val_loss: 2.2917 - val_accuracy: 0.2139
# Epoch 14/20
# 195/195 [==============================] - 10s 52ms/step - loss: 2.2885 - accuracy: 0.1913 - val_loss: 2.2833 - val_accuracy: 0.2025
# Epoch 15/20
# 195/195 [==============================] - 10s 53ms/step - loss: 2.2762 - accuracy: 0.1830 - val_loss: 2.2643 - val_accuracy: 0.1845
# Epoch 16/20
# 195/195 [==============================] - 10s 54ms/step - loss: 2.2407 - accuracy: 0.1818 - val_loss: 2.1964 - val_accuracy: 0.1825
# Epoch 17/20
# 195/195 [==============================] - 10s 53ms/step - loss: 2.1631 - accuracy: 0.1845 - val_loss: 2.1343 - val_accuracy: 0.1931
# Epoch 18/20
# 195/195 [==============================] - 11s 55ms/step - loss: 2.1246 - accuracy: 0.1983 - val_loss: 2.0926 - val_accuracy: 0.2243
# Epoch 19/20
# 195/195 [==============================] - 11s 54ms/step - loss: 2.0885 - accuracy: 0.2134 - val_loss: 2.0656 - val_accuracy: 0.2373
# Epoch 20/20
# 195/195 [==============================] - 11s 54ms/step - loss: 2.0604 - accuracy: 0.2265 - val_loss: 2.0386 - val_accuracy: 0.2432
